# %%
import os
import re
from collections import Counter
import subprocess
from pathlib import Path

import pandas as pd

import mgitools.os_helpers as os_helpers
import mgitools.bsub as bsub

# %% [markdown]
# ## set up directory structure from bammap

# %%
outer_dir = '/gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/'
run_dir = os.path.join(outer_dir, 'run_dir')

somaticwrapper_log_dir = os.path.join(outer_dir, 'logs')
reference_fp = '/gscmnt/gc2686/rna_editing/data/reference/gdc/GRCh38.d1.vd1.fa'

for fp in [outer_dir, run_dir, somaticwrapper_log_dir]:
    Path(fp).mkdir(exist_ok=True, parents=True)

# %%
bammap = pd.read_csv('../TCGA-TGCT.bammap', sep='\t')
bammap
# Out:
#                # sample_name          case disease experimental_strategy  \
# 0    TCGA-XE-AAO7.WXS.T.hg38  TCGA-XE-AAO7    TGCT                   WXS
# 1    TCGA-YU-A90R.WXS.T.hg38  TCGA-YU-A90R    TGCT                   WXS
# 2    TCGA-SN-A84Y.WXS.N.hg38  TCGA-SN-A84Y    TGCT                   WXS
# 3    TCGA-2G-AAFG.WXS.N.hg38  TCGA-2G-AAFG    TGCT                   WXS
# 4    TCGA-2G-AAGO.WXS.N.hg38  TCGA-2G-AAGO    TGCT                   WXS
# 5    TCGA-XE-A8H5.WXS.N.hg38  TCGA-XE-A8H5    TGCT                   WXS
# 6    TCGA-XE-AAOB.WXS.N.hg38  TCGA-XE-AAOB    TGCT                   WXS
# 7    TCGA-2G-AAF0.WXS.T.hg38  TCGA-2G-AAF0    TGCT                   WXS
# 8    TCGA-YU-A90S.WXS.N.hg38  TCGA-YU-A90S    TGCT                   WXS
# 9    TCGA-2G-AAIE.WXS.N.hg38  TCGA-2G-AAIE    TGCT                   WXS
# 10   TCGA-VF-A8AE.WXS.N.hg38  TCGA-VF-A8AE    TGCT                   WXS
# 11   TCGA-2G-AAHV.WXS.N.hg38  TCGA-2G-AAHV    TGCT                   WXS
# 12   TCGA-XE-AANH.WXS.N.hg38  TCGA-XE-AANH    TGCT                   WXS
# 13   TCGA-2G-AAI6.WXS.N.hg38  TCGA-2G-AAI6    TGCT                   WXS
# 14   TCGA-XE-AANM.WXS.N.hg38  TCGA-XE-AANM    TGCT                   WXS
# 15   TCGA-2G-AAII.WXS.N.hg38  TCGA-2G-AAII    TGCT                   WXS
# 16   TCGA-2G-AAFH.WXS.T.hg38  TCGA-2G-AAFH    TGCT                   WXS
# 17   TCGA-2G-AAHA.WXS.N.hg38  TCGA-2G-AAHA    TGCT                   WXS
# 18   TCGA-YU-A94A.WXS.T.hg38  TCGA-YU-A94A    TGCT                   WXS
# 19   TCGA-2G-AAL5.WXS.T.hg38  TCGA-2G-AAL5    TGCT                   WXS
# 20   TCGA-XE-AANX.WXS.N.hg38  TCGA-XE-AANX    TGCT                   WXS
# 21   TCGA-ZM-AA0D.WXS.T.hg38  TCGA-ZM-AA0D    TGCT                   WXS
# 22   TCGA-2G-AAEZ.WXS.N.hg38  TCGA-2G-AAEZ    TGCT                   WXS
# 23   TCGA-2G-AAGF.WXS.N.hg38  TCGA-2G-AAGF    TGCT                   WXS
# 24   TCGA-XE-AAO5.WXS.N.hg38  TCGA-XE-AAO5    TGCT                   WXS
# 25   TCGA-2G-AAHL.WXS.N.hg38  TCGA-2G-AAHL    TGCT                   WXS
# 26   TCGA-2G-AAIF.WXS.T.hg38  TCGA-2G-AAIF    TGCT                   WXS
# 27   TCGA-2G-AAFO.WXS.N.hg38  TCGA-2G-AAFO    TGCT                   WXS
# 28   TCGA-XE-AANV.WXS.N.hg38  TCGA-XE-AANV    TGCT                   WXS
# 29   TCGA-ZM-AA0E.WXS.T.hg38  TCGA-ZM-AA0E    TGCT                   WXS
# ..                       ...           ...     ...                   ...
# 305  TCGA-2G-AAH2.WXS.N.hg38  TCGA-2G-AAH2    TGCT                   WXS
# 306  TCGA-YU-A90V.WXS.N.hg38  TCGA-YU-A90V    TGCT                   WXS
# 307  TCGA-XE-AAO6.WXS.N.hg38  TCGA-XE-AAO6    TGCT                   WXS
# 308  TCGA-XE-AANU.WXS.T.hg38  TCGA-XE-AANU    TGCT                   WXS
# 309  TCGA-VF-A8A8.WXS.T.hg38  TCGA-VF-A8A8    TGCT                   WXS
# 310  TCGA-2G-AAHF.WXS.N.hg38  TCGA-2G-AAHF    TGCT                   WXS
# 311  TCGA-2G-AAGM.WXS.T.hg38  TCGA-2G-AAGM    TGCT                   WXS
# 312  TCGA-YU-A90R.WXS.N.hg38  TCGA-YU-A90R    TGCT                   WXS
# 313  TCGA-2G-AAEX.WXS.N.hg38  TCGA-2G-AAEX    TGCT                   WXS
# 314  TCGA-VF-A8A8.WXS.N.hg38  TCGA-VF-A8A8    TGCT                   WXS
# 315  TCGA-2G-AAGP.WXS.T.hg38  TCGA-2G-AAGP    TGCT                   WXS
# 316  TCGA-2G-AAKL.WXS.N.hg38  TCGA-2G-AAKL    TGCT                   WXS
# 317  TCGA-XY-A8S3.WXS.N.hg38  TCGA-XY-A8S3    TGCT                   WXS
# 318  TCGA-2G-AAEW.WXS.T.hg38  TCGA-2G-AAEW    TGCT                   WXS
# 319  TCGA-2G-AAHK.WXS.N.hg38  TCGA-2G-AAHK    TGCT                   WXS
# 320  TCGA-X3-A8G4.WXS.T.hg38  TCGA-X3-A8G4    TGCT                   WXS
# 321  TCGA-2G-AAH3.WXS.T.hg38  TCGA-2G-AAH3    TGCT                   WXS
# 322  TCGA-ZM-AA0N.WXS.N.hg38  TCGA-ZM-AA0N    TGCT                   WXS
# 323  TCGA-2G-AAGN.WXS.N.hg38  TCGA-2G-AAGN    TGCT                   WXS
# 324  TCGA-YU-A94L.WXS.T.hg38  TCGA-YU-A94L    TGCT                   WXS
# 325  TCGA-2G-AAFU.WXS.T.hg38  TCGA-2G-AAFU    TGCT                   WXS
# 326  TCGA-YU-AA61.WXS.N.hg38  TCGA-YU-AA61    TGCT                   WXS
# 327  TCGA-X3-A8G4.WXS.N.hg38  TCGA-X3-A8G4    TGCT                   WXS
# 328  TCGA-SN-A84W.WXS.N.hg38  TCGA-SN-A84W    TGCT                   WXS
# 329  TCGA-2G-AAIB.WXS.T.hg38  TCGA-2G-AAIB    TGCT                   WXS
# 330  TCGA-YU-A94B.WXS.N.hg38  TCGA-YU-A94B    TGCT                   WXS
# 331  TCGA-XE-AAOB.WXS.T.hg38  TCGA-XE-AAOB    TGCT                   WXS
# 332  TCGA-2G-AAI3.WXS.T.hg38  TCGA-2G-AAI3    TGCT                   WXS
# 333  TCGA-2G-AAGZ.WXS.T.hg38  TCGA-2G-AAGZ    TGCT                   WXS
# 334  TCGA-XE-AANZ.WXS.N.hg38  TCGA-XE-AANZ    TGCT                   WXS
#
#       sample_type                                          data_path  \
# 0           tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0264...
# 1           tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/02a7...
# 2    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0345...
# 3    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/070a...
# 4    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/07d8...
# 5    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/07e9...
# 6    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/08cc...
# 7           tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/095d...
# 8    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0a2a...
# 9    blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0ac8...
# 10   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0c15...
# 11   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0c33...
# 12   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0d21...
# 13   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/0f41...
# 14   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/100d...
# 15   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1047...
# 16          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/10f0...
# 17   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1213...
# 18          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1216...
# 19          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1259...
# 20   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1293...
# 21          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/137d...
# 22   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1569...
# 23   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/176c...
# 24   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/19d3...
# 25   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/19ec...
# 26          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/19f4...
# 27   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1a38...
# 28   blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1a6a...
# 29          tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/1b30...
# ..            ...                                                ...
# 305  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/e62b...
# 306  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/e8d7...
# 307  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/e9d2...
# 308         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/ea19...
# 309         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/ecbd...
# 310  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/ee3b...
# 311         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f0d0...
# 312  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f18f...
# 313  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f1ed...
# 314  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f234...
# 315         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f3da...
# 316  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f484...
# 317  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f542...
# 318         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f546...
# 319  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f571...
# 320         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f590...
# 321         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f681...
# 322  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f7aa...
# 323  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f7f1...
# 324         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f863...
# 325         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f888...
# 326  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f8fe...
# 327  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f940...
# 328  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f95d...
# 329         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f9b5...
# 330  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/fbfa...
# 331         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/fdb7...
# 332         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/fef6...
# 333         tumor  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/ff3d...
# 334  blood_normal  /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/fff1...
#
#         filesize data_format reference                                  UUID  \
# 0    62559578473         BAM      hg38  02645a88-2b1b-4390-8751-8d11681b138a
# 1    44291562018         BAM      hg38  02a7a293-24ab-42e7-b7ef-4ee53c76da8c
# 2    17000519818         BAM      hg38  03451dc0-4fd1-4718-a1c1-4b4bfa5efeac
# 3    12729573440         BAM      hg38  070ad00f-9136-4ada-950f-ede6bc641f15
# 4    13320338881         BAM      hg38  07d849ad-90b8-4067-8b45-e62a72514df5
# 5    14423250406         BAM      hg38  07e9af59-1016-45f3-bc5b-7d6c09c7624f
# 6    15353296172         BAM      hg38  08cc4424-aa6d-4f6e-93d5-02d7a257c532
# 7    41723582182         BAM      hg38  095d0d8f-cddf-47b1-ac22-1c75d7ec6870
# 8    17097528382         BAM      hg38  0a2a49d5-0a15-4378-ab1b-05495f4e015b
# 9    39055441574         BAM      hg38  0ac8fb26-062f-44f3-9333-7699fe645c05
# 10   15125635372         BAM      hg38  0c1509a4-aef9-44cd-8dca-cf712d378abd
# 11   31280731288         BAM      hg38  0c3362c5-e5aa-4e1e-b4c0-00675e6977f3
# 12   34387199837         BAM      hg38  0d216e09-f887-4b57-ab99-eb8dc51c814e
# 13   61695992011         BAM      hg38  0f4148c7-5630-46fc-932f-26edf16fb23e
# 14   39435489190         BAM      hg38  100d0291-9af7-49f9-bc36-6bd7da43b971
# 15   57896207491         BAM      hg38  10475829-5953-4a2f-84a1-2137dc859720
# 16   20607078887         BAM      hg38  10f03747-abe6-4c9c-be7f-e6e9eebfd797
# 17   15059903049         BAM      hg38  121392ed-1256-45fb-b344-cd794c8ff0fd
# 18   29493411788         BAM      hg38  1216ebff-c560-4a60-ba54-f647ff362a5e
# 19   13775973366         BAM      hg38  12595f6b-e5e0-4b86-a4a6-37dbdd924581
# 20   38593844961         BAM      hg38  1293e7b2-bd4f-4562-9f7f-b36d06c72388
# 21   12949993314         BAM      hg38  137d6754-dd9a-49d1-b640-e2b56f6e491b
# 22   40470065324         BAM      hg38  15698800-f890-48b3-b2cb-942257950864
# 23   11811579758         BAM      hg38  176cbf8b-618e-4406-96b9-ec4de86553e3
# 24   34714001701         BAM      hg38  19d3433b-783d-4d3b-ba11-309a733dfd14
# 25   16282821587         BAM      hg38  19ec2a00-6886-4c9e-a602-fd0503dcb786
# 26   54839159812         BAM      hg38  19f443b8-86fd-4cda-937b-66e9974daa87
# 27   15920236253         BAM      hg38  1a389c78-2fe9-4109-aceb-51d24150f3c2
# 28   16493447903         BAM      hg38  1a6a8be8-877f-48d2-b1ee-a22e36fb79a0
# 29   13015250683         BAM      hg38  1b3058a2-c45d-4ca9-8ae3-19e26f7f972d
# ..           ...         ...       ...                                   ...
# 305  15304934355         BAM      hg38  e62bba15-b6e4-4369-953b-1b5fc1b96777
# 306  34336506750         BAM      hg38  e8d79033-8547-4436-a878-8accd80a6970
# 307  16474099121         BAM      hg38  e9d26d9d-00a3-4b6d-bd4e-da43125599e7
# 308  30141747063         BAM      hg38  ea19d8a2-679a-4487-80b8-30dc80f5084b
# 309  20769039127         BAM      hg38  ecbd1245-2374-484a-a534-5edcd9384cc8
# 310  38813277042         BAM      hg38  ee3b6040-341b-47f5-9f23-6a9f472fc28b
# 311  15476187148         BAM      hg38  f0d0ed05-3ee2-4f55-bcab-3f2f5786a313
# 312  41507903281         BAM      hg38  f18fe04b-f74d-42ce-8033-270021987a52
# 313  15866248492         BAM      hg38  f1ed2f79-d423-4935-ba98-3a92f762f6c5
# 314  17329873366         BAM      hg38  f234368e-1e18-497b-b05f-eecc50f93769
# 315  15199525866         BAM      hg38  f3daae9b-6b45-4fbd-92b3-4b4adeffe572
# 316  15991109510         BAM      hg38  f484d2a5-639a-466e-99f6-31d9f4f3152d
# 317  13348271145         BAM      hg38  f542abaa-b16f-40f3-b88a-f1876cf2f33c
# 318  15594877879         BAM      hg38  f54698a3-c2b7-4a4f-a11b-8b20ae586d40
# 319  36969531793         BAM      hg38  f5713b81-5a4c-4b17-a229-56d43bb46623
# 320  13747772456         BAM      hg38  f590c324-179c-45d5-a710-fc45e3174390
# 321  18107288288         BAM      hg38  f6816983-be35-4d08-ae75-aceb99419530
# 322  12942595435         BAM      hg38  f7aaff31-6e90-4477-851a-4208ad3516b5
# 323  13444792203         BAM      hg38  f7f1159d-6d1a-4602-b180-ea5dfbbeadfa
# 324  32462844259         BAM      hg38  f8638ef9-8545-4505-a1b7-f5b87c6865cb
# 325  32317292577         BAM      hg38  f8889bee-94b8-4d1f-b9e5-9b13a0a76a9e
# 326  10710082005         BAM      hg38  f8fea0bb-6eda-4dab-bf71-f0cb65f5e013
# 327  14186557457         BAM      hg38  f94097f0-ba0d-4699-8e04-0c59736ec600
# 328  15271922533         BAM      hg38  f95d4ece-4644-42cf-9aa6-f64a6d1a68d7
# 329  31709749077         BAM      hg38  f9b5f938-fd7a-408a-b87d-89accfef927d
# 330  31836549376         BAM      hg38  fbfa9cb2-2567-4878-8af3-79a3113a5b6e
# 331  13931900837         BAM      hg38  fdb742a1-8849-4c24-b120-792c18b3a967
# 332  38779781756         BAM      hg38  fef6b5da-6e2c-404f-90fc-4e2bf431e6ea
# 333  14996809584         BAM      hg38  ff3d1d12-c60e-4a86-bf9f-a2067d0cf2e1
# 334  42047926844         BAM      hg38  fff171bd-dcfb-4369-99db-f1dd1ed1d8cc
#
#     system
# 0      MGI
# 1      MGI
# 2      MGI
# 3      MGI
# 4      MGI
# 5      MGI
# 6      MGI
# 7      MGI
# 8      MGI
# 9      MGI
# 10     MGI
# 11     MGI
# 12     MGI
# 13     MGI
# 14     MGI
# 15     MGI
# 16     MGI
# 17     MGI
# 18     MGI
# 19     MGI
# 20     MGI
# 21     MGI
# 22     MGI
# 23     MGI
# 24     MGI
# 25     MGI
# 26     MGI
# 27     MGI
# 28     MGI
# 29     MGI
# ..     ...
# 305    MGI
# 306    MGI
# 307    MGI
# 308    MGI
# 309    MGI
# 310    MGI
# 311    MGI
# 312    MGI
# 313    MGI
# 314    MGI
# 315    MGI
# 316    MGI
# 317    MGI
# 318    MGI
# 319    MGI
# 320    MGI
# 321    MGI
# 322    MGI
# 323    MGI
# 324    MGI
# 325    MGI
# 326    MGI
# 327    MGI
# 328    MGI
# 329    MGI
# 330    MGI
# 331    MGI
# 332    MGI
# 333    MGI
# 334    MGI
#
# [335 rows x 11 columns]

# %%
case_to_bams = {}
for i, row in bammap.iterrows():
    if row['case'] not in case_to_bams:
        case_to_bams[row['case']] = {}
    case_to_bams[row['case']][row['sample_type']] = row['data_path']
case_to_bams = {k:v for k, v in case_to_bams.items() if len(v)==2}
len(case_to_bams), sorted(case_to_bams.items())[:5]
# Out:
# (108,
#  [('TCGA-2G-AAER',
#    {'blood_normal': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/4284dd7c-c9ce-4bc4-a98e-2ebaee4b26e4/440bbe51-35bb-43ef-bb89-1c75eb34c16a_wxs_gdc_realn.bam',
#     'tumor': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/50648672-1f25-4f37-99d2-55f7b34f3a60/f77d49ed-575b-40cd-b2e9-8413c33c1694_wxs_gdc_realn.bam'}),
#   ('TCGA-2G-AAES',
#    {'tumor': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/483b4b01-80fd-4b28-aa82-1da191676913/da323434-58be-4479-ae68-5bab26f7a1eb_wxs_gdc_realn.bam',
#     'blood_normal': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/62a2056d-2c0b-4d67-a2a5-e794f87e08af/91dcaee8-ba9e-4c97-b4a5-0859293c711a_wxs_gdc_realn.bam'}),
#   ('TCGA-2G-AAEW',
#    {'blood_normal': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/5b1149fa-359e-44b1-9356-68f71e173da1/TCGA-2G-AAEW-10A-01D-A433-10_Illumina_gdc_realn.bam',
#     'tumor': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f54698a3-c2b7-4a4f-a11b-8b20ae586d40/TCGA-2G-AAEW-01A-11D-A42Y-10_Illumina_gdc_realn.bam'}),
#   ('TCGA-2G-AAEX',
#    {'tumor': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/450a0b15-25bc-42a7-a25b-43350f8a7b86/TCGA-2G-AAEX-01A-11D-A42Y-10_Illumina_gdc_realn.bam',
#     'blood_normal': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f1ed2f79-d423-4935-ba98-3a92f762f6c5/TCGA-2G-AAEX-10A-01D-A433-10_Illumina_gdc_realn.bam'}),
#   ('TCGA-2G-AAEY',
#    {'blood_normal': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/352570fd-5951-48fc-a483-6f0976a41a5b/18303c65-159a-4009-a5aa-3d9a0ccad24a_wxs_gdc_realn.bam',
#     'tumor': '/gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/4509e9b2-a545-44c3-9870-919717f4d80a/553de7ac-191b-4de3-bb21-21a5d59bb48b_wxs_gdc_realn.bam'})])

# %%
case_to_bams = {k:case_to_bams[k] for k in list(case_to_bams.keys())[:50]}
len(case_to_bams)
# Out:
# 50

# %%
## set up dir via symlink
commands = []
for case, fp_dict in case_to_bams.items():
    case_dir = os.path.join(run_dir, case)
    Path(case_dir).mkdir(exist_ok=True, parents=True)
    
    ## do normal
    fp = fp_dict['blood_normal']
    new_fp = os.path.join(case_dir, f'{case}.N.bam')
    commands.append(f'ln -s {fp} {new_fp}')
    ## do tumor
    fp = fp_dict['tumor']
    new_fp = os.path.join(case_dir, f'{case}.T.bam')
    commands.append(f'ln -s {fp} {new_fp}')
    
bsub.generate_bsub_bash_script(commands, 'python:3.7', os.path.join(outer_dir, 'symlink_commands.sh'),
                          min_memory=4, max_memory=5)

commands[:4]
# Out:
# ['ln -s /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/d5979bfc-cd27-4e8f-8db0-26430477d943/a1aa73dd-48a1-4ab8-ace0-fd78dd75a762_wxs_gdc_realn.bam /gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-XE-AAO7/TCGA-XE-AAO7.N.bam',
#  'ln -s /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/02645a88-2b1b-4390-8751-8d11681b138a/5a0b350a-b4b1-499f-b7cd-a40923b6534d_wxs_gdc_realn.bam /gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-XE-AAO7/TCGA-XE-AAO7.T.bam',
#  'ln -s /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/f18fe04b-f74d-42ce-8033-270021987a52/0482b17c-a7cb-425a-be64-6e5f3de6e4d3_wxs_gdc_realn.bam /gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-YU-A90R/TCGA-YU-A90R.N.bam',
#  'ln -s /gscmnt/gc2686/rna_editing/TCGA-TGCT/bams/02a7a293-24ab-42e7-b7ef-4ee53c76da8c/ce9e2239-0113-47f6-a42e-af4e40a1323e_wxs_gdc_realn.bam /gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-YU-A90R/TCGA-YU-A90R.T.bam']

# %%
## index directory structure

# %%
fps = sorted(os_helpers.listfiles(run_dir, regex='.bam$'))
len(fps), fps[:4]
# Out:
# (100,
#  ['/gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-2G-AAER/TCGA-2G-AAER.N.bam',
#   '/gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-2G-AAER/TCGA-2G-AAER.T.bam',
#   '/gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-2G-AAEX/TCGA-2G-AAEX.N.bam',
#   '/gscmnt/gc2686/rna_editing/TCGA-TGCT/somaticwrapper_50/run_dir/TCGA-2G-AAEX/TCGA-2G-AAEX.T.bam'])

# %%
def get_index_command(bam_fp):
    return f'samtools index {bam_fp}'

# %%
commands = [f'samtools index {fp}' for fp in fps]
bsub.generate_bsub_bash_script(commands, 'estorrs/slate:0.0.2', os.path.join(outer_dir, 'index_commands.sh'),
                          min_memory=10, max_memory=11)

# %% [markdown]
# ## generate sommaticwrapper command

# %%
perl somaticwrapper.pl --srg --step --sre --rdir --ref --log --q --mincovt --mincovn --minvaf --maxindsize --exonic

# %%
command = f'perl somaticwrapper.pl --rdir {run_dir} --log {somaticwrapper_log_dir} --step 0 \
--ref {reference_fp} -q research-hpc'
f = open(os.path.join(outer_dir, 'somaticwrapper_start.sh'), 'w')
f.write(command + '\n')
f.close()
